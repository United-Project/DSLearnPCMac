# %% [markdown]
# ### Necessary Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### A) Loading in the dataset using **read_csv**

# %%
college = pd.read_csv('College.csv')

# %% [markdown]
# ### B) Inspect the data

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# We do not want pandas to interpret the first column (unamed: 0) as data as it is just the names of universities.

# %%
# This will use the first column as the new way to index through the data frame.
college2 = pd.read_csv('College.csv', index_col=0)

# This will cause the name of the Unamed: 0 column to be "College" and we are setting the index to be the College column
college3 = college.rename({'Unnamed: 0': 'College'},
                          axis=1)
college3 = college3.set_index('College')

# %%
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# ### C) Use the describe() method of to produce a numerical summary of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### D) Use the pd.plotting.scatter_matrix() function to produce a scatterplot matrix of the first columns [Top10perc, Apps, Enroll]. Recall that you can reference a list C of columns of a data frame A using A[C].

# %%
cols_of_interest = college[['Top10perc', 'Apps', 'Enroll']]
pd.plotting.scatter_matrix(cols_of_interest);

# %% [markdown]
# ### E) Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private

# %%
# fig, ax = subplots(figsize=(8, 8)), we don't need this code from matplotlib but it gives more power over our plots 
college.boxplot('Outstate', by='Private');

# %% [markdown]
# ### F) Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.
# Then, Use the value_counts() method of college['Elite'] to see how many elite universities there are. Finally, use the boxplot() method again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college['Elite'] = pd.cut(college['Top10perc'],
                          [0,0.5,1],
                          labels =['No', 'Yes'])

# %%
college['Elite'].value_counts()
# Out:
# Elite
# Yes    3
# No     0
# Name: count, dtype: int64

# %%
college.boxplot('Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# ### G) Use the plot.hist() method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. c

# %%
import matplotlib.pyplot as plt

# Create a 2x2 grid of subplots
fig, ax = plt.subplots(2, 2, figsize=(10, 10))  # 2 rows, 2 columns

# Plot on each subplot
college.hist('Top10perc', color='blue', bins=12, ax=ax[0, 0])
college.hist('Top25perc', color='green', bins=12, ax=ax[0, 1])
college.hist('F.Undergrad', color='red', bins=12, ax=ax[1, 0])
college.hist('Outstate', color='purple', bins=12, ax=ax[1, 1])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### H) Continue exploring the data, and provide a brief summary of what you discover

# %%
fig, ax = subplots(figsize=(8, 8))
y = college['Top10perc']
x = college['Room.Board']

ax.plot(x, y)

# %% [markdown]
# Summary: although this graph is fucked, we can see that as we get closer to the top 10 percent or 100th percentile of the top 10 percent, room and board increases in price roughly.

# %% [markdown]
# ## 9. This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %% [markdown]
# ### a) Which of the predictors are quantitative, and which are qualitative?

# %%
# Reading in our dataframe
auto = pd.read_csv('auto.csv')

# Find type of variables
print(auto.dtypes)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %% [markdown]
# ### b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.

# %%
# Will be using the min() and max() methods of numpy
for value in auto:
    print('Min: ', value.min())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Will be using the min() and max() methods of numpy
#       2 for value in auto:
# ----> 3     print('Min: ', value.min())
#
# AttributeError: 'str' object has no attribute 'min'

# %% [markdown]
# ### c) What is the mean and standard deviation of each quantitative predictor?
